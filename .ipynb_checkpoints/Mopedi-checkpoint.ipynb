# %%
from csv import DictReader
import operator
import matplotlib.pyplot as plt

mopedi = dict()

for j in range(2015,2020):    
    for i in range(1,13):
        file = 'podatki/Podatki_{:02d}'.format(i) + str(j) + '.csv'
        podatki = DictReader(open(file, 'rt', encoding='ANSI'), delimiter=';')
        
        if str(i) + '_' + str(j) not in mopedi:
            mopedi[str(i) + '_' + str(j)] = 0

        for row in podatki:
            status = str(row['Status vozila (opis)'])
            try:
                vrsta_vozila = str(row['J-Kategorija in vrsta vozila (opis)'])
                
                if status == 'registrirano' and vrsta_vozila == 'moped-dvokolo':
                    mopedi[str(i) + '_' + str(j)] += 1
                    
            except:
                #Napaka v datumu vozila
                None

# %%
meseci = list(mopedi.keys())
st_mopedov = list(mopedi.values())

plt.plot(meseci, st_mopedov, label='Število registriranih mopedov')
plt.xlabel('Meseci')
plt.xticks(rotation=45)
plt.yticks([5, 5.5, 6, 6.5])
plt.ylabel('Starost uvoženih vozil')
plt.legend()
plt.show()
# Out:
# [34, 103, 181, 286, 277, 376, 381, 292, 189, 96, 72, 51, 85, 86, 169, 354, 381, 392, 383, 280, 203, 91, 71, 83, 71, 124, 506, 5030, 3943, 2061, 1368, 947, 447, 271, 135, 134, 183, 55, 263, 507, 702, 642, 482, 412, 229, 170, 83, 44, 44, 76, 222, 304, 292, 370, 394, 292, 182, 120, 64, 56]
